# %%
from make_gif import prompt_to_gif
import tensorflow as tf

# %%
imported = tf.keras.models.load_model('Models\\ByzantineRNN.h5')

prompt_to_gif('Tapmaps\\test3', 'J', imported, predict=True)
print('Complete!')
# Out:
# Complete!

# %% [markdown]
# ---
